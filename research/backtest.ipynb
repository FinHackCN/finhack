# %%
import pandas as pd
import importlib
import os
import sys
sys.path.append('/data/code/finhack')
from library.backtest import bt

bt_instance=bt.run(cash=300000,strategy_name="aiTopN",data_path="/tmp/lgb_model.pkl")
bt.analyse(bt_instance,'000001.SH')
# Out:
# strategy time:12.913257598876953
#              returns      values
# trade_date
# 2010-01-04  1.042891    1.042891
# 2010-01-05  1.015026    1.058562
# 2010-01-06  0.993551    1.051735
# 2010-01-07  0.888234    0.934187
# 2010-01-08  1.007125    0.940843
# ...              ...         ...
# 2022-11-09  0.996783  361.521450
# 2022-11-10  0.977246  353.295243
# 2022-11-11  0.981627  346.804013
# 2022-11-14  1.009043  349.940317
# 2022-11-15  1.035007  362.190597
#
# [3126 rows x 2 columns]
#                 close   returns    values
# trade_date
# 2010-01-04  3243.7600       NaN       NaN
# 2010-01-05  3282.1790  1.011844  1.011844
# 2010-01-06  3254.2150  0.991480  1.003223
# 2010-01-07  3192.7760  0.981120  0.984282
# 2010-01-08  3195.9970  1.001009  0.985275
# ...               ...       ...       ...
# 2022-11-09  3048.1676  0.994673  0.939702
# 2022-11-10  3036.1318  0.996051  0.935992
# 2022-11-11  3087.2926  1.016851  0.951764
# 2022-11-14  3083.4013  0.998740  0.950564
# ...
