# %%
# %load_ext autoreload
# %autoreload 2
import pandas as pd
import importlib
import os
import sys
sys.path.append('/data/code/finhack')

# %%
from factors.factorManager import factorManager

# %%
#根据single_factors目录下已经计算好的csv，获取全部因子列表
factorManager.getFactorsList()
# Out:
# ['MIDDLE_0',
#  'HIGHWAVE',
#  'alpha191_162',
#  'pe_0',
#  'alpha101_088',
#  'buySmVol_0',
#  'MINUSDM_14_0',
#  'alpha191_060',
#  'impaiTtm',
#  'AD_14_0',
#  'CMO_0',
#  'alpha191_011',
#  'alpha101_071',
#  'SPINNINGTOP',
#  'alpha101_101',
#  'netprofitYoy',
#  'alpha191_079',
#  'alpha191_154',
#  'alpha191_051',
#  'alpha191_126',
#  'circMv_0',
#  'alpha191_036',
#  'sellElgAmount_0',
#  'alpha101_019',
#  'alpha101_052',
#  'qOpQoq',
#  'MACD_0',
#  'RSI_0',
#  'alpha191_025',
#  'AROONDOWN_14_0',
#  'AROONDOWN_0',
#  'trYoy',
#  'alpha101_027',
#  'alpha191_037',
#  'alpha191_107',
#  'MIN_120_0',
#  'alpha101_094',
#  'alpha101_013',
#  'dtNetprofitYoy',
#  'sellLgAmount_0',
#  'qDtRoe',
#  'alpha101_032',
#  'alpha191_173',
#  'alpha191_077',
#  'alpha101_066',
#  'alpha101_045',
#  'alpha101_073',
#  'alpha191_038',
#  'alpha191_102',
#  'FASTKRSI_0',
#  'alpha101_077',
#  'TRIX_14_0',
#  'pb_0',
#  'alpha191_033',
#  'SAREXT_0',
#  'alpha191_117',
#  'BOP_14_0',
# ...

# %%
#获取alpha列表的列表
factorManager.getAlphaLists()
# Out:
# ['alpha191', 'alpha101', 'alphaA', 'label']

# %%
#根据alpha列表获取alpha
factorManager.getAlphaList('alphaA')
# Out:
# ['$close/$UPPER_0\n',
#  '$close/$MIDDLE_0\n',
#  '$close/$LOWER_0\n',
#  '$close/$DEMA_0\n',
#  '$close/$EMA_90_0\n',
#  '$close/$HTTRENDLINE_0\n',
#  '$close/$MA_90_0\n',
#  '$close/$MAMA_0\n',
#  '$close/$FAMA_0\n',
#  '$close/$MIDPOINT_0\n',
#  '$close/$MIDPRICE_0\n',
#  '$close/$SAR_0\n',
#  '$close/$SAREXT_0\n',
#  '$close/$SMA_0\n',
#  '$close/$T3_0\n',
#  '$close/$TEMA_0\n',
#  '$close/$TRIMA_0\n',
#  '$close/$WMA_0\n',
#  '$close/$MAX_120_0\n',
#  '$close/$MIN_120_0\n',
#  '$close/$PPSR_0\n',
#  '$close/$PPR1_0\n',
#  '$close/$PPR2_0\n',
#  '$close/$PPR3_0\n',
#  '$close/$PPS1_0\n',
#  '$close/$PPS2_0\n',
#  '$close/$PPS3_0\n',
#  '$netMfAmount_0/$totalMv_0\n',
#  'mean($netMfAmount_0,5)/$totalMv_0\n',
#  'mean($netMfAmount_0,5)/mean($netMfAmount_0,20)\n',
#  '$pe_0/$peTtm_0']

# %%
factorManager.getIndicatorsList()
# Out:
# ['PPSR',
#  'PPR1',
#  'PPS1',
#  'PPR2',
#  'PPS2',
#  'PPR3',
#  'PPS3',
#  'EMO',
#  'buySmVol',
#  'buySmAmount',
#  'sellSmVol',
#  'sellSmAmount',
#  'buyMdVol',
#  'buyMdAmount',
#  'sellMdVol',
#  'sellMdAmount',
#  'buyLgVol',
#  'buyLgAmount',
#  'sellLgVol',
#  'sellLgAmount',
#  'buyElgVol',
#  'buyElgAmount',
#  'sellElgVol',
#  'sellElgAmount',
#  'netMfVol',
#  'netMfAmount',
#  'lAmp',
#  'lFcRatio',
#  'lFlRatio',
#  'lFdAmount',
#  'lFirstTime',
#  'lLastTime',
#  'lOpenTimes',
#  'lStrth',
#  'lLimit',
#  'UPPER',
#  'MIDDLE',
#  'LOWER',
#  'DEMA',
#  'EMA',
#  'HTTRENDLINE',
#  'MA',
#  'MAMA',
#  'FAMA',
#  'MIDPOINT',
#  'MIDPRICE',
#  'SAR',
#  'SAREXT',
#  'SMA',
#  'T3',
#  'TEMA',
#  'TRIMA',
#  'WMA',
#  'ADX',
#  'ADXR',
#  'APO',
#  'AROONDOWN',
#  'ARRONUP',
#  'AROONOSC',
#  'BOP',
#  'CCI',
#  'CMO',
#  'DX',
#  'MACD',
#  'MACDSIGNAL',
#  'MACDHIST',
#  'MACDX',
#  'MACDSIGNALX',
#  'MACDHISTX',
#  'MACDFIX',
#  'MACDSIGNALFIX',
#  'MACDHISTFIX',
# ...

# %%
factorManager.getAnalysedIndicatorsList()
# Out:
# ['buySmVol_0',
#  'impaiTtm_0',
#  'sellElgAmount_0',
#  'CMO_0',
#  'circMv_0',
#  'qDtRoe_0',
#  'MIDDLE_0',
#  'STDDEV_0',
#  'roeYearly_0',
#  'MACD_0',
#  'RSI_0',
#  'AROONDOWN_0',
#  'ebtYoy_0',
#  'roe_0',
#  'pe_0',
#  'TAN_0',
#  'ATR_0',
#  'BELTHOLD_0',
#  'MEDPRICE_0',
#  'qRoe_0',
#  'sellLgAmount_0',
#  'UNIQUE3RIVER_0',
#  'cfps_0',
#  'opIncome_0',
#  'LONGLEGGEDDOJI_0',
#  'qOcfToSales_0',
#  'SAREXT_0',
#  'FASTKRSI_0',
#  'totalShare_0',
#  'AROONOSC_0',
#  'LINEARREG_0',
#  'cfpsYoy_0',
#  'pb_0',
#  'TRISTAR_0',
#  'turnoverRate_0',
#  'buyLgVol_0',
#  'sellSmVol_0',
#  'MACDHIST_0',
#  'buyMdVol_0',
#  'LINEARREGSLOPE_0',
#  'diluted2Eps_0',
#  'TEMA_0',
#  'opYoy_0',
#  'ocfYoy_0',
#  'MIDPRICE_0',
#  'HIKKAKE_0',
#  'ROC_0',
#  'ocfps_0',
#  'LINEARREGINTERCEPT_0',
#  'SLOWK_0',
#  'revenuePs_0',
#  'PLUSDI_0',
#  'HTTRENDLINE_0',
#  'DX_0',
#  '3OUTSIDE_0',
#  'buyMdAmount_0',
#  'close_0',
#  'basicEpsYoy_0',
#  'buySmAmount_0',
#  'roaYearly_0',
# ...

# %%
from factors.factorAnalyzer import factorAnalyzer
factorAnalyzer.analys('alphaA_001')
# Out:
# factor_name:alphaA_001
# factor_name:alphaA_001,IC=-0.20783379118886458,IR=-1.1120900445756183,IRR=-6.94272279848515,score=1.6046707574610142

# %%
# %%time
factorManager.getFactors(['pe_0','buySmVol_0','sellElgAmount_0','alpha101_001','alpha191_001','CMO_0','circMv_0','qDtRoe_0','MIDDLE_0','STDDEV_0','roeYearly_0','MACD_0','RSI_0','AROONDOWN_0','ebtYoy_0','roe_0','pe_0','TAN_0','ATR_0','BELTHOLD_0','MEDPRICE_0'])
# Out:
# /data/code/finhack/data/factors/single_factors/qDtRoe_0.csv not found
# /data/code/finhack/data/factors/single_factors/STDDEV_0.csv not found
# /data/code/finhack/data/factors/single_factors/roeYearly_0.csv not found
# /data/code/finhack/data/factors/single_factors/ebtYoy_0.csv not found
# /data/code/finhack/data/factors/single_factors/roe_0.csv not found
# /data/code/finhack/data/factors/single_factors/TAN_0.csv not found
# /data/code/finhack/data/factors/single_factors/ATR_0.csv not found
# /data/code/finhack/data/factors/single_factors/BELTHOLD_0.csv not found
# /data/code/finhack/data/factors/single_factors/MEDPRICE_0.csv not found
# CPU times: user 1min 46s, sys: 17.9 s, total: 2min 4s
# Wall time: 2min 4s
#                          pe_0  buySmVol_0  sellElgAmount_0  alpha101_001  \
# ts_code   trade_date
# 000001.SZ 20000104    37.1344         NaN              NaN           NaN
#           20000105    36.6674         NaN              NaN           NaN
# ...

# %%
# %%time
factorManager.getFactors(['pe_0','buySmVol_0','sellElgAmount_0','alpha101_001','alpha191_001'])
# Out:
# CPU times: user 42.1 s, sys: 7.98 s, total: 50.1 s
# Wall time: 50.1 s
#                          pe_0  buySmVol_0  sellElgAmount_0  alpha101_001  \
# ts_code   trade_date
# 000001.SZ 20000104    37.1344         NaN              NaN           NaN
#           20000105    36.6674         NaN              NaN           NaN
#           20000106    38.1293         NaN              NaN           NaN
#           20000107    39.6723         NaN              NaN           NaN
#           20000110    40.8905         NaN              NaN           NaN
# ...                       ...         ...              ...           ...
# 688981.SH 20230426    37.9831    198587.0        125526.50     -0.378074
#           20230427    38.0680    108293.0         59948.72     -0.332520
#           20230428    40.2166     89031.0         56466.50     -0.433449
#           20230504    38.3749    126354.0         78560.11     -0.141967
#           20230505    38.4011     65083.0         24986.54     -0.190515
# ...
