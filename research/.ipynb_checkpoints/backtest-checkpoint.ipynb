# %%
import pandas as pd
import importlib
import os
import sys
sys.path.append('/data/code/finhack')
from library.backtest import bt

bt_instance=bt.run(cash=300000,strategy_name="aiTopN",data_path="/data/code/finhack/data/preds/lgb_model_220307debdebb09278eefd2653a3c32b_pred.pkl")
result=bt.analyse(bt_instance,'000001.SH')
print(result)
# Out:
# strategy time:12.121858596801758
#              returns       values
# trade_date
# 2010-01-04  1.002797     1.002797
# 2010-01-05  0.998966     1.001760
# 2010-01-06  1.001409     1.003172
# 2010-01-07  0.977632     0.980733
# 2010-01-08  1.014326     0.994783
# ...              ...          ...
# 2022-11-09  1.024185  1951.015781
# 2022-11-10  0.983406  1918.641301
# 2022-11-11  1.001961  1922.403875
# 2022-11-14  1.020695  1962.187078
# 2022-11-15  1.021467  2004.308848
#
# [3126 rows x 2 columns]
#                 close   returns    values
# trade_date
# 2010-01-04  3243.7600       NaN       NaN
# 2010-01-05  3282.1790  1.011844  1.011844
# 2010-01-06  3254.2150  0.991480  1.003223
# 2010-01-07  3192.7760  0.981120  0.984282
# 2010-01-08  3195.9970  1.001009  0.985275
# ...               ...       ...       ...
# 2022-11-09  3048.1676  0.994673  0.939702
# 2022-11-10  3036.1318  0.996051  0.935992
# 2022-11-11  3087.2926  1.016851  0.951764
# 2022-11-14  3083.4013  0.998740  0.950564
# 2022-11-15  3134.0778  1.016435  0.966187
#
# [3126 rows x 3 columns]
# <h4>Performance Metrics</h4>
#                            Strategy     Benchmark
# -------------------------  -----------  -----------
# Start Period               2010-01-04   2010-01-04
# End Period                 2022-11-15   2022-11-15
# Risk-Free Rate             0.0%         0.0%
# Time in Market             100.0%       100.0%
#
# Cumulative Return          199,771.89%  -4.51%
# CAGR﹪                     80.49%       -0.36%
#
# Sharpe                     2.12         0.09
# Prob. Sharpe Ratio         100.0%       61.95%
# Smart Sharpe               1.77         0.07
# Sortino                    3.11         0.12
# Smart Sortino              2.59         0.1
# Sortino/√2                 2.2          0.08
# Smart Sortino/√2           1.83         0.07
# Omega                      1.42         1.42
#
# Max Drawdown               -49.47%      -52.3%
# Longest DD Days            1403         2710
# Volatility (ann.)          31.17%       20.76%
# R^2                        0.55         0.55
# Information Ratio          0.19         0.19
# Calmar                     1.63         -0.01
# Skew                       -0.52        -0.77
# Kurtosis                   1.69         5.65
#
# Expected Daily %           0.24%        -0.0%
# Expected Monthly %         5.03%        -0.03%
# Expected Yearly %          79.43%       -0.35%
# Kelly Criterion            17.57%       -7.56%
# Risk of Ruin               0.0%         0.0%
# Daily Value-at-Risk        -2.97%       -2.14%
# Expected Shortfall (cVaR)  -2.97%       -2.14%
#
# Max Consecutive Wins       28           11
# Max Consecutive Losses     9            9
# Gain/Pain Ratio            0.42         0.02
# Gain/Pain (1M)             2.54         0.07
#
# Payoff Ratio               0.95         0.8
# Profit Factor              1.42         1.02
# Common Sense Ratio         1.51         1.08
# CPC Index                  0.81         0.42
# Tail Ratio                 1.06         1.06
# Outlier Win Ratio          2.67         4.6
# Outlier Loss Ratio         3.11         5.21
#
# MTD                        10.2%        8.32%
# 3M                         -3.85%       -4.36%
# 6M                         7.16%        1.61%
# YTD                        -10.15%      -13.89%
# 1Y                         15.62%       -11.44%
# 3Y (ann.)                  15.98%       1.89%
# 5Y (ann.)                  26.05%       -1.0%
# 10Y (ann.)                 119.39%      4.31%
# All-time (ann.)            80.49%       -0.36%
#
# Best Day                   7.58%        5.76%
# Worst Day                  -9.26%       -8.49%
# Best Month                 85.9%        20.57%
# Worst Month                -19.47%      -22.65%
# Best Year                  1172.88%     52.87%
# Worst Year                 -39.02%      -24.59%
#
# Avg. Drawdown              -5.04%       -9.76%
# Avg. Drawdown Days         35           332
# Recovery Factor            4038.13      -0.09
# Ulcer Index                0.17         0.34
# Serenity Index             691.18       -0.0
#
# Avg. Up Month              12.87%       4.74%
# Avg. Down Month            -6.25%       -5.15%
# Win Days %                 59.84%       52.34%
# Win Month %                61.94%       50.97%
# Win Quarter %              71.15%       48.08%
# Win Year %                 84.62%       53.85%
#
# Beta                       1.11         -
# Alpha                      0.64         -
# Correlation                74.15%       -
# Treynor Ratio              179434.16%   -
# None
# <h4>5 Worst Drawdowns</h4>
#         Start      Valley         End  Days  Max Drawdown  99% Max Drawdown
# 1  2010-11-02  2012-12-03  2014-09-05  1403    -49.471332        -45.786803
# 2  2015-06-15  2015-08-26  2015-12-30   198    -46.380979        -45.552299
# 3  2010-04-13  2010-07-02  2010-10-08   178    -27.667916        -26.857358
# 4  2021-09-16  2021-11-16  2022-11-15   425    -26.315578        -25.738506
# 5  2020-02-26  2020-05-22  2020-07-29   154    -25.298413        -23.790210
# <h4>Strategy Visualization</h4>
# findfont: Font family ['Arial'] not found. Falling back to DejaVu Sans.
# /root/anaconda3/lib/python3.9/site-packages/quantstats/stats.py:968: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   returns = returns.pivot('Year', 'Month', 'Returns').fillna(0)
# /root/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py:82: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
