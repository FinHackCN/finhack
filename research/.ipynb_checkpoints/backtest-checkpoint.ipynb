# %%
import pandas as pd
import importlib
import os
import sys
sys.path.append('/data/code/finhack')
from library.backtest import bt





bt_instance=bt.run(cash=30000,strategy_name="aiTopN",data_path="/tmp/lgb_model.pkl")
print(bt_instance['returns'])
print(bt_instance['total_value'])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [1], in <cell line: 6>()
#       4 import sys
#       5 sys.path.append('/data/cache/finhack')
# ----> 6 from library.backtest import bt
#      12 bt_instance=bt.run(cash=30000,strategy_name="aiTopN",data_path="/tmp/lgb_model.pkl")
#      13 print(bt_instance['returns'])
#
# ModuleNotFoundError: No module named 'library'
